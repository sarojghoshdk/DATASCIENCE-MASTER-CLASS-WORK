# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# to delete (drop) a column
df.drop('PassengerId' , axis = 1 , inplace = True)    
                    # axis = 0 means ROW & axis = 1 means COLUMN (bidifauult axis = 0)
                    # inplace = False means it is not delete parmanantly means it is present in main Datafream
                    # inplace = True means it is delete parmanantly means it is not present in main Datafream

# %%
# to delete a row
df.drop(3 , inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# to set index
df.set_index('Name' , inplace = True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
# to reset index means the bidifault index is come again in dataframe
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1' : [3,4,5,6,7],
      'key2' : [5,6,7,8,9],
      'key3' : [4,5,6,7,8]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     9     8

# %%
df1 = pd.read_csv('taxonomy.csv.xls - taxonomy.csv.xls.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# drop / delete all NaN value
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5    0101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5    0101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1) # delete column in which NaN present
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5    0101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2 = pd.read_csv("taxonomy.csv.xls - taxonomy.csv.xls.csv")

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis = 1) # delete column in which NaN present
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3    0101-02-01             Help Pay for Food
# 4    0101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285  0111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna('saroj')     # fillna() to fill the NaN place by saroj
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency     saroj                 saroj
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3    0101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4    0101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285  0111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# grouping
g = df.groupby('Survived')

# %%
g

# %%
g.sum()    # get overall sum
# Out:
# /tmp/ipykernel_116/367457815.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()    # get overall sum
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()      # average
# Out:
# /tmp/ipykernel_116/2415215095.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()      # average
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_116/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_116/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max().T
# Out:
# /tmp/ipykernel_116/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_116/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df5 = df[['Name' , 'Survived' , 'Pclass']][0:5]

# %%
df6 = df[['Name' , 'Survived' , 'Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5 , df6])       # to mearge 2 dataframe row wise
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5 , df6] , axis = 1)       # to mearge 2 dataframe column wise

# %%
df7
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %%
df7.fillna('saroj')    # NaN portion is filled up by saroj
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3                           Allen, Mr. William Henry      0.0    3.0
# 4                                   Moran, Mr. James      0.0    3.0
# 5                                              saroj    saroj  saroj
# 6                                              saroj    saroj  saroj
# 7                                              saroj    saroj  saroj
# 8                                              saroj    saroj  saroj
# 9                                              saroj    saroj  saroj
#
#                                                 Name Survived Pclass
# 0                                              saroj    saroj  saroj
# 1                                              saroj    saroj  saroj
# ...

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [6,7,8,9,10],
                      'key3' : [11,12,13,14,15]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
data2 = pd.DataFrame({'key1' : [1,2,31,44,5],
                      'key4' : [61,71,81,91,10],
                      'key5' : [111,121,13,114,15]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    61   111
# 1     2    71   121
# 2    31    81    13
# 3    44    91   114
# 4     5    10    15

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    61   111
# 1     2    71   121
# 2    31    81    13
# 3    44    91   114
# 4     5    10    15

# %%
pd.merge(data1 , data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6    11    61   111
# 1     2     7    12    71   121
# 2     5    10    15    10    15

# %%
pd.merge(data1,data2,how = 'left')    # data1 = left & data2 = right
# Out:
#    key1  key2  key3  key4   key5
# 0     1     6    11  61.0  111.0
# 1     2     7    12  71.0  121.0
# 2     3     8    13   NaN    NaN
# 3     4     9    14   NaN    NaN
# 4     5    10    15  10.0   15.0

# %%
pd.merge(data1,data2,how = 'right')    # data1 = left & data2 = right
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0  11.0    61   111
# 1     2   7.0  12.0    71   121
# 2    31   NaN   NaN    81    13
# 3    44   NaN   NaN    91   114
# 4     5  10.0  15.0    10    15

# %%
pd.merge(data1,data2,how = 'outer')    # outer means left & right both
# Out:
#    key1  key2  key3  key4   key5
# 0     1   6.0  11.0  61.0  111.0
# 1     2   7.0  12.0  71.0  121.0
# 2     3   8.0  13.0   NaN    NaN
# 3     4   9.0  14.0   NaN    NaN
# 4     5  10.0  15.0  10.0   15.0
# 5    31   NaN   NaN  81.0   13.0
# 6    44   NaN   NaN  91.0  114.0

# %%
pd.merge(data1,data2,how = 'cross')  # cross means it match all element
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6    11       1    61   111
# 1        1     6    11       2    71   121
# 2        1     6    11      31    81    13
# 3        1     6    11      44    91   114
# 4        1     6    11       5    10    15
# 5        2     7    12       1    61   111
# 6        2     7    12       2    71   121
# 7        2     7    12      31    81    13
# 8        2     7    12      44    91   114
# 9        2     7    12       5    10    15
# 10       3     8    13       1    61   111
# 11       3     8    13       2    71   121
# 12       3     8    13      31    81    13
# 13       3     8    13      44    91   114
# 14       3     8    13       5    10    15
# 15       4     9    14       1    61   111
# 16       4     9    14       2    71   121
# 17       4     9    14      31    81    13
# 18       4     9    14      44    91   114
# 19       4     9    14       5    10    15
# 20       5    10    15       1    61   111
# ...

# %%
data1 = pd.DataFrame({'key1' : [1,2,3,4,5],
                      'key2' : [6,7,8,9,10],
                      'key3' : [11,12,13,14,15]},
                     index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({'key11' : [1,2,3,4,5],
                      'key22' : [6,7,8,9,10],
                      'key33' : [11,12,13,14,15]},
                     index = ['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     6    11
# b     2     7    12
# c     3     8    13
# d     4     9    14
# e     5    10    15

# %%
data2
# Out:
#    key11  key22  key33
# a      1      6     11
# b      2      7     12
# h      3      8     13
# i      4      9     14
# j      5     10     15

# %%
data1.join(data2) # join() works on index & merge() work on column
                  # join is bidiffault how = left
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     6    11    1.0    6.0   11.0
# b     2     7    12    2.0    7.0   12.0
# c     3     8    13    NaN    NaN    NaN
# d     4     9    14    NaN    NaN    NaN
# e     5    10    15    NaN    NaN    NaN

# %%
data1.join(data2 , how = 'right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   6.0  11.0      1      6     11
# b   2.0   7.0  12.0      2      7     12
# h   NaN   NaN   NaN      3      8     13
# i   NaN   NaN   NaN      4      9     14
# j   NaN   NaN   NaN      5     10     15

# %%
data1.join(data2 , how = 'inner')    # inner show commom b/w data1 &data2
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     6    11      1      6     11
# b     2     7    12      2      7     12

# %%
data1.join(data2 , how = 'outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   6.0  11.0    1.0    6.0   11.0
# b   2.0   7.0  12.0    2.0    7.0   12.0
# c   3.0   8.0  13.0    NaN    NaN    NaN
# d   4.0   9.0  14.0    NaN    NaN    NaN
# e   5.0  10.0  15.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    3.0    8.0   13.0
# i   NaN   NaN   NaN    4.0    9.0   14.0
# j   NaN   NaN   NaN    5.0   10.0   15.0

# %%
data1.join(data2 , how = 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     6    11      1      6     11
# 1      1     6    11      2      7     12
# 2      1     6    11      3      8     13
# 3      1     6    11      4      9     14
# 4      1     6    11      5     10     15
# 5      2     7    12      1      6     11
# 6      2     7    12      2      7     12
# 7      2     7    12      3      8     13
# 8      2     7    12      4      9     14
# 9      2     7    12      5     10     15
# 10     3     8    13      1      6     11
# 11     3     8    13      2      7     12
# 12     3     8    13      3      8     13
# 13     3     8    13      4      9     14
# 14     3     8    13      5     10     15
# 15     4     9    14      1      6     11
# 16     4     9    14      2      7     12
# 17     4     9    14      3      8     13
# 18     4     9    14      4      9     14
# 19     4     9    14      5     10     15
# 20     5    10    15      1      6     11
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# convert Fare in INR (ruppese) from URO
df['Fare_INR'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
def euro_inr(x):
    return x*80

df['Fare_INR'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %%
def cat_fare(x):
    if x < 10:
        return "cheap"
    elif x >= 10 and x < 20:
        return "mid"
    else:
        return "high"

# %%
df['cat_fare'] = df['Fare'].apply(cat_fare)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...
